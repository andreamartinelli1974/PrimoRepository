# %%
"""Progetto_gruppo3.ipynb
"""

#%% IMPORT SECTION
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier 
from sklearn.ensemble import RandomForestClassifier
from sklearn import ensemble 
from sklearn import tree

#%% DIRECTORY SETTINGS
# Change work directory
os.chdir('//srv0001/Risorse/Public/Gruppo3-Python')
cwd = os.getcwd()
print(cwd)


#%% PREPARE FUNCTION
def prepare_data(data):
   
    features = data.drop(["REF_DATE", "SEDOLCHK", "ICB_INDUSTRY_NUM", "ICB_SECTOR_NUM"], axis=1).astype("float64")
        
    return features
# Out:
# \\srv0001\Risorse\Public\Gruppo3-Python

# %%
#%% IMPORT DATA
#Import .csv
clean_data = pd.read_csv(r'Data/clean2.csv', sep=',')
companynames = pd.read_csv(r'Data/companynames.csv', sep=',')
companynames = companynames.drop_duplicates(subset = "SEDOLCHK")
print(clean_data.head(10))

sectors_dict = {'1':'Oil & Gas','1000':'Basic Materials','2000':'Industrial','3000':'Consumer Good','4000':'Health Care','5000':'Consumer Services','6000':'Telecomunications','7000':'Utilities','8000':'Financials','9000':'Technology'}
# Out:
#    REF_DATE SEDOLCHK  SIMPLE_TOT_RET  COMPOUND_TOT_RET  FIVE_YR_VOLATILITY_M  \
# 0  20050429    96162        0.061576          0.061576              0.393006
# 1  20050429  5713422        0.160714          0.160714              0.345234
# 2  20050429  BFRSRR7        0.048899          0.048899              0.210220
# 3  20050429   309644        0.133696          0.133696              0.350844
# 4  20050429  BYXS699       -0.026759         -0.026759              0.654300
# 5  20050429   180366        0.049464          0.049464              0.304141
# 6  20050429  7086650        0.077516          0.077516              0.294512
# 7  20050429  B1QH830        0.052083          0.052083              0.305665
# 8  20050429  B1XH026        0.065292          0.065605              0.214153
# 9  20050429  4061393        0.107707          0.107968              0.317072
#
#    FIVE_YR_VOLATILITY_W       ADY      AERR      AGRE       APE  ...  \
# 0              0.394376  0.021675  0.714570  0.126908  13.16874  ...
# 1              0.367468  0.025000  0.507042  1.186080  19.71832  ...
# 2              0.226989  0.035242  0.601581  0.103386  11.30512  ...
# 3              0.326956  0.077681  0.000000  0.026424  13.40449  ...
# 4              0.669824  0.000000  1.000000  0.083212  36.36430  ...
# 5              0.290389  0.046166  0.533644  0.141072  10.10163  ...
# 6              0.305476  0.003993  0.908676  1.612952  22.86968  ...
# 7              0.301718  0.043403  0.479899  1.380812  11.98312  ...
# 8              0.224755  0.030144  0.603623  0.084048  13.14926  ...
# 9              0.368014  0.020219  0.696875  0.358257  14.99186  ...
#
#    REV_STD_MARK       ROE   TRL_ECM   TRL_GRE  TURNOVER_1M  UL_SALES  \
# 0     -0.000167  0.252909  0.023294  0.079338    10.631300  0.038443
# 1      0.003257  0.133236  0.157033  0.373592    16.174480  0.051881
# 2     -0.003808  0.139480 -0.044052 -0.108124     5.043304  0.055346
# 3      0.000026  0.222408 -0.062505 -0.040259    16.308010  0.135606
# 4      0.000353  0.148208  0.047023  0.244651     4.625721  0.260557
# 5     -0.014570  0.199096 -0.066363 -0.049020    20.975460  0.190406
# 6      0.000727  0.174013 -0.168524  0.438229     2.348297  0.084520
# 7      0.006095  0.165192  0.140747  0.196250   100.735200  0.078789
# 8      0.001129  0.241901  0.098319  0.104781    52.311330  0.065228
# 9      0.001367  0.168243  0.058378  0.159656     9.697785  0.153569
#
#     PB_PCF_1   PB_PCF_2  ICB_INDUSTRY_NUM  ICB_SECTOR_NUM
# 0   8.815166   8.815166              2000            2350
# 1   7.777806   7.777806              2000            2750
# 2   8.254547   8.254547              3000            3570
# 3  11.831260  11.831260              2000            2790
# 4  20.795810  20.795810              4000            4570
# 5   2.341711   9.474795              8000            8770
# 6   5.188351   5.188351              2000            2720
# 7   5.507106   5.507106              2000            2750
# 8   6.292714   6.292714              2000            2350
# 9   4.070660   4.070660              3000            3760
#
# [10 rows x 69 columns]

# %%
#%% K-FOLD VALIDATION
valid = clean_data.to_numpy(copy=True)
N = valid.shape[0]
K = 10                                         # number of folds
preds_kfold = np.empty(N)
folds = np.random.randint(0, K, size=N)

for idx in np.arange(K):
    # For each fold, break your data into training and testing subsets
    data_train = pd.DataFrame(valid[folds != idx,:],columns=['REF_DATE','SEDOLCHK','SIMPLE_TOT_RET','COMPOUND_TOT_RET','FIVE_YR_VOLATILITY_M','FIVE_YR_VOLATILITY_W','ADY','AERR','AGRE','APE','CGR','CV3Y_EPS','CV3Y_EREV_FY1','CV3Y_REP_EPS','CV3Y_REV_MARK','CV5Y_EPS','CV6M_P','CV6M_PM6M','DEBT_MKT_CAP','DY_FWD','DY_TRL','EBIT_SALES','ECM','EEREV','EPS_SIGMA','EPSDISP','EREV','F2GRE','FDY','FERR','FGRE','FPE','FWD_ECM','FWD_GRE','LRE','MKT_CAP_SALES','NM','PB','PCF','PCTCHG_DPS','PCTCHG_EBIT','PCTCHG_EBIT_MARGIN','PCTCHG_EBITDA','PCTCHG_EQUITY','PCTCHG_NET_DEBT','PCTCHG_NM','PCTCHG_PRE_TAX_PROFIT','PCTCHG_ROE','PCTCHG_SALES','PCTCHG_UL_SALES','PE_FWD','PE_TRL','PM6M','RC1MEEREV','RC1MEREV','REC_MARK_1M','REC_MARK_3M','REV_MARK_1M','REV_MARK_3M','REV_STD_MARK','ROE','TRL_ECM','TRL_GRE','TURNOVER_1M','UL_SALES','PB_PCF_1','PB_PCF_2', 'ICB_INDUSTRY_NUM', 'ICB_SECTOR_NUM'])
    data_test  = pd.DataFrame(valid[folds == idx,:],columns=['REF_DATE','SEDOLCHK','SIMPLE_TOT_RET','COMPOUND_TOT_RET','FIVE_YR_VOLATILITY_M','FIVE_YR_VOLATILITY_W','ADY','AERR','AGRE','APE','CGR','CV3Y_EPS','CV3Y_EREV_FY1','CV3Y_REP_EPS','CV3Y_REV_MARK','CV5Y_EPS','CV6M_P','CV6M_PM6M','DEBT_MKT_CAP','DY_FWD','DY_TRL','EBIT_SALES','ECM','EEREV','EPS_SIGMA','EPSDISP','EREV','F2GRE','FDY','FERR','FGRE','FPE','FWD_ECM','FWD_GRE','LRE','MKT_CAP_SALES','NM','PB','PCF','PCTCHG_DPS','PCTCHG_EBIT','PCTCHG_EBIT_MARGIN','PCTCHG_EBITDA','PCTCHG_EQUITY','PCTCHG_NET_DEBT','PCTCHG_NM','PCTCHG_PRE_TAX_PROFIT','PCTCHG_ROE','PCTCHG_SALES','PCTCHG_UL_SALES','PE_FWD','PE_TRL','PM6M','RC1MEEREV','RC1MEREV','REC_MARK_1M','REC_MARK_3M','REV_MARK_1M','REV_MARK_3M','REV_STD_MARK','ROE','TRL_ECM','TRL_GRE','TURNOVER_1M','UL_SALES','PB_PCF_1','PB_PCF_2', 'ICB_INDUSTRY_NUM', 'ICB_SECTOR_NUM'])
    #%% PREPARE FEATURES
    features = prepare_data(data_train)
    #print(features)

    for col in data_train.columns:
        if data_train[col].dtype==object and col!='SEDOLCHK':
            data_train[col]=pd.to_numeric(data_train[col],errors='coerce')
        
    for col in data_test.columns:
        if data_test[col].dtype==object and col!='SEDOLCHK':
            data_test[col]=pd.to_numeric(data_test[col],errors='coerce')
        
        #%% SINGLE TREE
    model = tree.DecisionTreeClassifier(max_depth = 20)
    model.fit(features, data_train["ICB_INDUSTRY_NUM"])
    
    print(model.score(prepare_data(data_train), data_train["ICB_INDUSTRY_NUM"]))
    print(model.score(prepare_data(data_test), data_test["ICB_INDUSTRY_NUM"]))

#plt.figure(figsize=[30.0, 30.0])
#tree.plot_tree(model, feature_names=features.columns)
# Out:
# 0.8507558938577017
# 0.79841449603624
# 0.8424094501500359
# 0.7928286852589641
# 0.8464604389563158
# 0.7872240045291564
# 0.8405126905697031
# 0.7914995224450811
# 0.8463335235800199
# 0.7963488460083239
# 0.8490460512430881
# 0.7964881980426022
# 0.8459134767645631
# 0.7933078393881453
# 0.8479964559578934
# 0.8015223046536275
# 0.8423587566145949
# 0.7881815586640023
# 0.8473579557473453
# 0.7919721752209062

# %%
#%% GET THE OUTLIERS SEDOLCHK & names
predicted = model.predict(prepare_data(data_test))
g_truth = data_test["ICB_INDUSTRY_NUM"].to_numpy(copy=True)

outliers_sedol = pd.DataFrame(data_test["SEDOLCHK"])
outliers_sedol['ICB_INDUSTRY_NUM'] = data_test["ICB_INDUSTRY_NUM"]
outliers_sedol['REF_DATE'] = data_test["REF_DATE"]
outliers_sedol['PREDICTED'] = predicted


rowtodrop = np.where(predicted == g_truth)[0]

outliers_sedol = outliers_sedol.drop(outliers_sedol.index[rowtodrop])

outliers = outliers_sedol.merge(companynames, left_on='SEDOLCHK', right_on='SEDOLCHK')

outliers["ICB_INDUSTRY_NUM"] = outliers["ICB_INDUSTRY_NUM"].astype(str)
outliers["ICB_INDUSTRY_NUM"] = outliers["ICB_INDUSTRY_NUM"].map(sectors_dict)
outliers["PREDICTED"] = outliers["PREDICTED"].astype(str)
outliers["PREDICTED"] = outliers["PREDICTED"].map(sectors_dict)

print(outliers)

outliers.to_excel(excel_writer = 'Tree_Outliers.xlsx')
# Out:
#      SEDOLCHK   ICB_INDUSTRY_NUM  REF_DATE          PREDICTED  \
# 0     5051605  Telecomunications  20050429          Oil & Gas
# 1     5051605  Telecomunications  20151231      Consumer Good
# 2     BDZZRW1          Oil & Gas  20050429      Consumer Good
# 3     BDZZRW1          Oil & Gas  20060630         Industrial
# 4     BDZZRW1          Oil & Gas  20090430         Industrial
# ...       ...                ...       ...                ...
# 2012  BKJ9RT5         Industrial  20191129  Consumer Services
# 2013  7085259        Health Care  20191129      Consumer Good
# 2014  BZ12WP8    Basic Materials  20191129      Consumer Good
# 2015  B0744B3         Industrial  20191129  Consumer Services
# 2016  BDZV116         Industrial  20191129        Health Care
#
#                               NAME
# 0     HELLENIC TELECOMMUN ORGANIZA
# 1     HELLENIC TELECOMMUN ORGANIZA
# 2                       SAIPEM SPA
# 3                       SAIPEM SPA
# 4                       SAIPEM SPA
# ...                            ...
# 2012                       ISS A/S
# 2013                H LUNDBECK A/S
# 2014                     LINDE PLC
# 2015                     BUNZL PLC
# 2016                   EPIROC AB-A
#
# [2017 rows x 5 columns]

# %%
#%% RANDOM FOREST
for idx in np.arange(K):
    # For each fold, break your data into training and testing subsets
    data_train = pd.DataFrame(valid[folds != idx,:],columns=['REF_DATE','SEDOLCHK','SIMPLE_TOT_RET','COMPOUND_TOT_RET','FIVE_YR_VOLATILITY_M','FIVE_YR_VOLATILITY_W','ADY','AERR','AGRE','APE','CGR','CV3Y_EPS','CV3Y_EREV_FY1','CV3Y_REP_EPS','CV3Y_REV_MARK','CV5Y_EPS','CV6M_P','CV6M_PM6M','DEBT_MKT_CAP','DY_FWD','DY_TRL','EBIT_SALES','ECM','EEREV','EPS_SIGMA','EPSDISP','EREV','F2GRE','FDY','FERR','FGRE','FPE','FWD_ECM','FWD_GRE','LRE','MKT_CAP_SALES','NM','PB','PCF','PCTCHG_DPS','PCTCHG_EBIT','PCTCHG_EBIT_MARGIN','PCTCHG_EBITDA','PCTCHG_EQUITY','PCTCHG_NET_DEBT','PCTCHG_NM','PCTCHG_PRE_TAX_PROFIT','PCTCHG_ROE','PCTCHG_SALES','PCTCHG_UL_SALES','PE_FWD','PE_TRL','PM6M','RC1MEEREV','RC1MEREV','REC_MARK_1M','REC_MARK_3M','REV_MARK_1M','REV_MARK_3M','REV_STD_MARK','ROE','TRL_ECM','TRL_GRE','TURNOVER_1M','UL_SALES','PB_PCF_1','PB_PCF_2', 'ICB_INDUSTRY_NUM', 'ICB_SECTOR_NUM'])
    data_test  = pd.DataFrame(valid[folds == idx,:],columns=['REF_DATE','SEDOLCHK','SIMPLE_TOT_RET','COMPOUND_TOT_RET','FIVE_YR_VOLATILITY_M','FIVE_YR_VOLATILITY_W','ADY','AERR','AGRE','APE','CGR','CV3Y_EPS','CV3Y_EREV_FY1','CV3Y_REP_EPS','CV3Y_REV_MARK','CV5Y_EPS','CV6M_P','CV6M_PM6M','DEBT_MKT_CAP','DY_FWD','DY_TRL','EBIT_SALES','ECM','EEREV','EPS_SIGMA','EPSDISP','EREV','F2GRE','FDY','FERR','FGRE','FPE','FWD_ECM','FWD_GRE','LRE','MKT_CAP_SALES','NM','PB','PCF','PCTCHG_DPS','PCTCHG_EBIT','PCTCHG_EBIT_MARGIN','PCTCHG_EBITDA','PCTCHG_EQUITY','PCTCHG_NET_DEBT','PCTCHG_NM','PCTCHG_PRE_TAX_PROFIT','PCTCHG_ROE','PCTCHG_SALES','PCTCHG_UL_SALES','PE_FWD','PE_TRL','PM6M','RC1MEEREV','RC1MEREV','REC_MARK_1M','REC_MARK_3M','REV_MARK_1M','REV_MARK_3M','REV_STD_MARK','ROE','TRL_ECM','TRL_GRE','TURNOVER_1M','UL_SALES','PB_PCF_1','PB_PCF_2', 'ICB_INDUSTRY_NUM', 'ICB_SECTOR_NUM'])
    #%% PREPARE FEATURES
    features = prepare_data(data_train)
    #print(features)

    for col in data_train.columns:
        if data_train[col].dtype==object and col!='SEDOLCHK':
            data_train[col]=pd.to_numeric(data_train[col],errors='coerce')
        
    for col in data_test.columns:
        if data_test[col].dtype==object and col!='SEDOLCHK':
            data_test[col]=pd.to_numeric(data_test[col],errors='coerce')
            
    forest = ensemble.RandomForestClassifier(n_estimators=100, bootstrap=True, max_features=None)
    forest.fit(features, data_train["ICB_INDUSTRY_NUM"])
    print(forest.score(prepare_data(data_train), data_train["ICB_INDUSTRY_NUM"]))
    print(forest.score(prepare_data(data_test), data_test["ICB_INDUSTRY_NUM"]))

# %%
#%% GET THE OUTLIERS SEDOLCHK & names
predicted_f = forest.predict(prepare_data(data_test))
g_truth_f = data_test["ICB_INDUSTRY_NUM"].to_numpy(copy=True)

outliers_sedol_f = pd.DataFrame(data_test["SEDOLCHK"])
outliers_sedol_f['ICB_INDUSTRY_NUM'] = data_test["ICB_INDUSTRY_NUM"]
outliers_sedol_f['PREDICTED'] = predicted_f

rowtodrop_f = np.where(predicted_f == g_truth_f)[0]

outliers_sedol_f = outliers_sedol_f.drop(outliers_sedol_f.index[rowtodrop_f])

outliers_f = outliers_sedol_f.merge(companynames, left_on='SEDOLCHK', right_on='SEDOLCHK')

outliers_f["ICB_INDUSTRY_NUM"] = outliers_f["ICB_INDUSTRY_NUM"].astype(str)
outliers_f["ICB_INDUSTRY_NUM"] = outliers_f["ICB_INDUSTRY_NUM"].map(sectors_dict)
outliers_f["PREDICTED"] = outliers_f["PREDICTED"].astype(str)
outliers_f["PREDICTED"] = outliers_f["PREDICTED"].map(sectors_dict)

print(outliers_f)

outliers_f.to_excel(excel_writer = 'Forest_Outliers.xlsx')
# Out:
#    SEDOLCHK   ICB_INDUSTRY_NUM          PREDICTED  \
# 0   B97C733  Telecomunications    Basic Materials
# 1   7108899         Industrial         Technology
# 2   4557104         Industrial      Consumer Good
# 3   B1XFTL2         Technology         Industrial
# 4   3174300      Consumer Good         Industrial
# 5   4354134         Technology         Industrial
# 6   BDQQ1Q5    Basic Materials          Utilities
# 7   B12PJ24      Consumer Good         Industrial
# 8   4305507        Health Care    Basic Materials
# 9   B4T92J8  Consumer Services    Basic Materials
# 10  B1Z7RQ7  Consumer Services         Industrial
# 11  B096LW7          Oil & Gas    Basic Materials
# 12  7050417         Industrial  Telecomunications
# 13  4792132      Consumer Good         Industrial
# 14  5069211        Health Care      Consumer Good
# 15  BYQ7HZ6  Consumer Services          Oil & Gas
# 16  5086577    Basic Materials          Oil & Gas
#
#                             NAME
# 0                 TELE2 AB-B SHS
# 1                    ABB LTD-REG
# 2                   GEA GROUP AG
# 3               HEXAGON AB-B SHS
# 4             BURBERRY GROUP PLC
# 5   UNITED INTERNET AG-REG SHARE
# 6             HOLMEN AB-B SHARES
# 7             HUSQVARNA AB-B SHS
# 8               PERRIGO CORP DAC
# 9   KABEL DEUTSCHLAND HOLDING AG
# 10                TUI TRAVEL LTD
# 11                  FUGRO NV-CVA
# 12          DORMAKABA HOLDING AG
# 13                        SEB SA
# 14                  BAYER AG-REG
# 15               TAKEAWAY.COM NV
# 16                       BASF SE
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\workbook.py in close(self)
#     315             try:
# --> 316                 self._store_workbook()
#     317             except IOError as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     631         except IOError as e:
# --> 632             raise e
#     633
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     629             xlsx_file = ZipFile(self.filename, "w", compression=ZIP_DEFLATED,
# --> 630                                 allowZip64=self.allow_zip64)
#     631         except IOError as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64)
#    1089                 try:
# -> 1090                     self.fp = io.open(file, filemode)
#    1091                 except OSError:
#
# PermissionError: [Errno 13] Permission denied: 'Forest_Outliers.xlsx'
#
# During handling of the above exception, another exception occurred:
#
# FileCreateError                           Traceback (most recent call last)
# <ipython-input-39-548b0c42dcef> in <module>
#      20 print(outliers_f)
#      21
# ---> 22 outliers_f.to_excel(excel_writer = 'Forest_Outliers.xlsx')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2178             startcol=startcol,
#    2179             freeze_panes=freeze_panes,
# -> 2180             engine=engine,
#    2181         )
#    2182
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     736         )
#     737         if need_save:
# --> 738             writer.save()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\excel\_xlsxwriter.py in save(self)
#     193         """
#     194
# --> 195         return self.book.close()
#     196
#     197     def write_cells(
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\workbook.py in close(self)
#     316                 self._store_workbook()
#     317             except IOError as e:
# --> 318                 raise FileCreateError(e)
#     319             except LargeZipFile as e:
#     320                 raise FileSizeError("Filesize would require ZIP64 extensions. "
#
# FileCreateError: [Errno 13] Permission denied: 'Forest_Outliers.xlsx'

# %%
#%% GET THE FEATURES IMPORTANCE

def show_features(forest, X, y):
  importances = forest.feature_importances_

  # Calcola deviazione standard per plottare errore
  std = np.std([tree.feature_importances_ for tree in forest.estimators_],
              axis=0)
  indices = np.argsort(importances)[::-1]

  # Print the feature ranking
  print("Feature ranking:")

  for f in range(X.shape[1]):
      print("%d. feature %s (%f)" % (indices[f], features.columns[indices[f]], importances[indices[f]]))

  # Plot the feature importances of the forest
  plt.figure(figsize=(20,20))
  plt.title("Feature importances")
  plt.bar(range(X.shape[1]), importances[indices],
        color="r", yerr=std[indices], align="center")
  plt.xticks(range(X.shape[1]), indices)
  plt.xlim([-1, X.shape[1]])
  plt.show()
  
show_features(forest, features, data_train["ICB_INDUSTRY_NUM"])
# Out:
# Feature ranking:
# 63. feature PB_PCF_1 (0.212629)
# 16. feature DEBT_MKT_CAP (0.055363)
# 19. feature EBIT_SALES (0.049507)
# 61. feature TURNOVER_1M (0.042668)
# 36. feature PCF (0.041748)
# 33. feature MKT_CAP_SALES (0.040420)
# 58. feature ROE (0.028547)
# 2. feature FIVE_YR_VOLATILITY_M (0.027766)
# 3. feature FIVE_YR_VOLATILITY_W (0.027241)
# 34. feature NM (0.027115)
# 27. feature FERR (0.026621)
# 13. feature CV5Y_EPS (0.026121)
# 5. feature AERR (0.025161)
# 12. feature CV3Y_REV_MARK (0.024927)
# 35. feature PB (0.023491)
# 11. feature CV3Y_REP_EPS (0.022095)
# 17. feature DY_FWD (0.018539)
# 41. feature PCTCHG_EQUITY (0.016276)
# 9. feature CV3Y_EPS (0.015578)
# 23. feature EPSDISP (0.014593)
# 31. feature FWD_GRE (0.014529)
# 8. feature CGR (0.013112)
# 32. feature LRE (0.012573)
# 46. feature PCTCHG_SALES (0.012122)
# 10. feature CV3Y_EREV_FY1 (0.011653)
# 37. feature PCTCHG_DPS (0.009849)
# 42. feature PCTCHG_NET_DEBT (0.009500)
# 48. feature PE_FWD (0.008927)
# 64. feature PB_PCF_2 (0.008832)
# 22. feature EPS_SIGMA (0.008122)
# 43. feature PCTCHG_NM (0.007820)
# 18. feature DY_TRL (0.007669)
# 39. feature PCTCHG_EBIT_MARGIN (0.007284)
# 26. feature FDY (0.006365)
# 40. feature PCTCHG_EBITDA (0.005959)
# 49. feature PE_TRL (0.005811)
# 60. feature TRL_GRE (0.005633)
# 4. feature ADY (0.005218)
# 29. feature FPE (0.005103)
# 6. feature AGRE (0.005030)
# 44. feature PCTCHG_PRE_TAX_PROFIT (0.005009)
# 38. feature PCTCHG_EBIT (0.004658)
# 62. feature UL_SALES (0.004259)
# 47. feature PCTCHG_UL_SALES (0.004003)
# 7. feature APE (0.003955)
# 50. feature PM6M (0.003796)
# 14. feature CV6M_P (0.003769)
# 45. feature PCTCHG_ROE (0.003645)
# 25. feature F2GRE (0.003032)
# 28. feature FGRE (0.002845)
# 15. feature CV6M_PM6M (0.002563)
# 59. feature TRL_ECM (0.002510)
# 56. feature REV_MARK_3M (0.002189)
# 30. feature FWD_ECM (0.002047)
# 21. feature EEREV (0.001818)
# 20. feature ECM (0.001814)
# 24. feature EREV (0.001730)
# 54. feature REC_MARK_3M (0.001444)
# 1. feature COMPOUND_TOT_RET (0.001210)
# 0. feature SIMPLE_TOT_RET (0.001196)
# 55. feature REV_MARK_1M (0.001124)
# 57. feature REV_STD_MARK (0.001093)
# 53. feature REC_MARK_1M (0.001032)
# 52. feature RC1MEREV (0.000873)
# 51. feature RC1MEEREV (0.000872)
